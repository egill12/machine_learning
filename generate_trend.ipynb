# %%
import numpy as np
#np.random.seed(1)
n_samples = 1000
b = 0.1 #  ( range from -0.2 to 0.2 to move from mean reversion to strong trend
a = (1/(1-(b**3)))
x = w = np.random.normal(size=n_samples)
for t in range(n_samples):
    x[t] = a*x[t-1] + w[t]
    
from matplotlib import pyplot as plt
plt.plot(x)
plt.show()

# %%
#np.random.normal(0,1,10)
#np.random.normal(size=n_samples)
from generate_trend import generate_trend
# alpha a value between -0.5 to 0.15
ts = generate_trend(1000,0.15)

# %%
from matplotlib import pyplot as plt
plt.plot(ts)
plt.show()
